# %%
import pandas as pd
import numpy as np
import re
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

# %%
pub_data = pd.read_csv('/content/public_data_labeled.csv')
cyb_twt = pd.read_csv('/content/cyberbullying_tweets.csv')

# %%
data = pd.read_csv('/content/data.csv', sep='\t', header=None)
data1set= pd.read_csv('/content/data1set.csv')
dataset = pd.read_csv('/content/dataset.csv')

# %% [markdown]
# # pub_data

# %%
pub_data.head()
pub_data.columns=['label','tweet']
pub_data.head()
# Out:
#            label                                              tweet
# 0  Non-offensive  !!! RT @mayasolovely: As a woman you shouldn't...
# 1      Offensive  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2      Offensive  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3      Offensive  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4      Offensive  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...

# %%
for i in range(pub_data.shape[0]):
  if pub_data['label'].iloc[i]=='Non-offensive':
    pub_data['label'].iloc[i]=0
  else:
    pub_data['label'].iloc[i]=1

# %%
pub_data.head()
# Out:
#   label                                              tweet
# 0     0  !!! RT @mayasolovely: As a woman you shouldn't...
# 1     1  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2     1  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3     1  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4     1  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...

# %%
pub_data.head()

# %% [markdown]
# # data

# %%
data.columns=['id','tweet','label']
data.pop('id')

# %%
for i in range(data.shape[0]):
  if data['label'].iloc[i]=='none':
    data['label'].iloc[i]=0
  else:
    data['label'].iloc[i]=1

# %%
data.head(10)
# Out:
#                                                tweet label
# 0  RT @colonelkickhead: Another bloody instant re...     0
# 1  @azzamalirhabi @JihadiA8 This video of the Pes...     0
# 2  Oh really? No more instant restaurants? THAT'S...     0
# 3  RT @Benfrancisallen: It hasn't been a good few...     0
# 4  RT @NoToFeminism: I don’t need femisnsn becaus...     0
# 5      @MariachiMacabre 19% is not the vast majority     0
# 6  @DianH4 @ExposeFalsehood And it is Muslims who...     1
# 7  @truaemusic @mattybboi83 @Number10gov Capital ...     1
# 8  RT @fruitondabottom: #FeminismisEQUALITYwhen M...     1
# 9  Gather round, kids. It's story time, brought t...     0

# %% [markdown]
# # Cyb_twt

# %%
cyb_twt

# %%
cyb_twt.columns=['tweet','label']

# %%
cyb_twt.head()
# Out:
#                                                tweet              label
# 0  In other words #katandandre, your food was cra...  not_cyberbullying
# 1  Why is #aussietv so white? #MKR #theblock #ImA...  not_cyberbullying
# 2  @XochitlSuckkks a classy whore? Or more red ve...  not_cyberbullying
# 3  @Jason_Gio meh. :P  thanks for the heads up, b...  not_cyberbullying
# 4  @RudhoeEnglish This is an ISIS account pretend...  not_cyberbullying

# %%
for i in range(cyb_twt.shape[0]):
  if cyb_twt['label'].iloc[i]=='not_cyberbullying':
    cyb_twt['label'].iloc[i]=0
  else:
    cyb_twt['label'].iloc[i]=1

# %%
cyb_twt['label'].value_counts()
# Out:
# 1    39747
# 0     7945
# Name: label, dtype: int64

# %% [markdown]
# # data1set

# %%
data1set.columns=["label","tweet"]

# %%
data1set.head()
# Out:
#    label                                              tweet
# 0      0  yeah I got 2 backups for all that. I just hate...
# 1      0  I hate using my BB  but love my iPhone. Haven'...
# 2      1                             Get fucking real dude.
# 3      1   She is as dirty as they come  and that crook ...
# 4      1   why did you fuck it up. I could do it all day...

# %% [markdown]
# # dataset

# %%
dataset.columns=["tweet","label"]

# %%
dataset.head()
# Out:
#                                                tweet  label
# 0                               "You fuck your dad."      1
# 1  "i really don't understand your point.\xa0 It ...      0
# 2  "A\\xc2\\xa0majority of Canadians can and has ...      0
# 3  "listen if you dont wanna get married to a man...      0
# 4  "C\xe1c b\u1ea1n xu\u1ed1ng \u0111\u01b0\u1edd...      0

# %% [markdown]
# # combine

# %%
datacomb3 = pd.concat([pub_data,cyb_twt])

# %%
datacomb3.head()
# Out:
#   label                                              tweet
# 0     0  !!! RT @mayasolovely: As a woman you shouldn't...
# 1     1  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2     1  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3     1  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4     1  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...

# %%
datacomb3['label'].value_counts()
# Out:
# 1    60367
# 0    12108
# Name: label, dtype: int64

# %%
data1comb=pd.read_csv('/content/data1comb.csv')

# %%
data1comb['label'].value_counts()
# Out:
# 1    29911
# 0    26333
# Name: label, dtype: int64

# %%
cyb_twts=pd.read_csv('/content/cyberbullying_tweets.csv')

# %%
cyb_twts.columns=['tweet','label']

# %%
cyb_twts['label'].value_counts()
# Out:
# religion               7998
# age                    7992
# gender                 7973
# ethnicity              7961
# not_cyberbullying      7945
# other_cyberbullying    7823
# Name: label, dtype: int64

# %%
for i in range(cyb_twt.shape[0]):
  if cyb_twt['label'].iloc[i]=='not_cyberbullying':
    cyb_twt['label'].iloc[i]=0
  elif cyb_twt['label'].iloc[i]=='age':
    cyb_twt['label'].iloc[i]=2
  else:
    cyb_twt['label'].iloc[i]=1

# %%
datacomb4 = pd.concat([data,cyb_twt])

# %% [markdown]
# # download

# %%
from google.colab import files
tweet_df.to_csv('output.csv', encoding = 'utf-8-sig') 
files.download('output.csv')
